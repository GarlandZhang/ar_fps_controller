# %%
import numpy as np
import cv2
import os

# %%
def interpret(history, inp):
    if len(history) == 0:
        history.append(inp)
        print('nothing')
        return
    
    last_move = history[-1]
    print('last_move: {} | inp: {}'.format(last_move, inp))
    history.append(inp)
    if inp == 'curl':
        return 'shoot'
    elif inp == 'point_foreward':
        return 'stop'
    elif inp == 'point_up':
        return 'reload'
    else:
        print('nothing')
        return

# %%
labels = ['point_foreward', 'point_up', 'curl']


num_values = 100
inps = np.random.choice(labels, num_values)
print(inps)

history = []

for i, inp in enumerate(inps):
    action = interpret(history, inp)
    if action is not None:
        print('{} => {}: do action: {}'.format(len(history) - 2, len(history) - 1, action))
# Out:
# ['curl' 'point_up' 'point_up' 'point_up' 'curl' 'curl' 'point_up'
#  'point_up' 'point_foreward' 'curl' 'point_foreward' 'point_up' 'point_up'
#  'point_foreward' 'point_foreward' 'curl' 'point_foreward' 'curl'
#  'point_foreward' 'point_up' 'point_foreward' 'curl' 'curl'
#  'point_foreward' 'point_up' 'point_foreward' 'curl' 'point_foreward'
#  'point_foreward' 'point_foreward' 'point_up' 'curl' 'point_up' 'curl'
#  'point_up' 'point_foreward' 'point_up' 'point_foreward' 'curl' 'curl'
#  'curl' 'curl' 'curl' 'point_foreward' 'point_foreward' 'curl' 'curl'
#  'curl' 'curl' 'point_up' 'point_up' 'point_up' 'curl' 'curl'
#  'point_foreward' 'point_foreward' 'point_up' 'point_foreward'
#  'point_foreward' 'point_up' 'point_foreward' 'point_up' 'point_up' 'curl'
#  'point_foreward' 'curl' 'point_up' 'point_up' 'point_up' 'curl' 'curl'
#  'curl' 'curl' 'curl' 'point_foreward' 'curl' 'point_up' 'curl' 'curl'
#  'curl' 'point_up' 'point_up' 'point_up' 'point_foreward' 'curl'
#  'point_up' 'curl' 'curl' 'point_foreward' 'point_foreward'
#  'point_foreward' 'curl' 'point_up' 'point_foreward' 'point_foreward'
#  'point_foreward' 'curl' 'point_up' 'curl' 'point_foreward']
# nothing
# last_move: curl | inp: point_up
# 0 => 1: do action: reload
# last_move: point_up | inp: point_up
# 1 => 2: do action: reload
# last_move: point_up | inp: point_up
# 2 => 3: do action: reload
# last_move: point_up | inp: curl
# 3 => 4: do action: shoot
# last_move: curl | inp: curl
# 4 => 5: do action: shoot
# last_move: curl | inp: point_up
# 5 => 6: do action: reload
# last_move: point_up | inp: point_up
# 6 => 7: do action: reload
# last_move: point_up | inp: point_foreward
# 7 => 8: do action: stop
# last_move: point_foreward | inp: curl
# 8 => 9: do action: shoot
# last_move: curl | inp: point_foreward
# 9 => 10: do action: stop
# last_move: point_foreward | inp: point_up
# 10 => 11: do action: reload
# last_move: point_up | inp: point_up
# 11 => 12: do action: reload
# last_move: point_up | inp: point_foreward
# 12 => 13: do action: stop
# last_move: point_foreward | inp: point_foreward
# 13 => 14: do action: stop
# last_move: point_foreward | inp: curl
# 14 => 15: do action: shoot
# last_move: curl | inp: point_foreward
# 15 => 16: do action: stop
# last_move: point_foreward | inp: curl
# 16 => 17: do action: shoot
# last_move: curl | inp: point_foreward
# 17 => 18: do action: stop
# last_move: point_foreward | inp: point_up
# 18 => 19: do action: reload
# last_move: point_up | inp: point_foreward
# 19 => 20: do action: stop
# last_move: point_foreward | inp: curl
# 20 => 21: do action: shoot
# last_move: curl | inp: curl
# 21 => 22: do action: shoot
# last_move: curl | inp: point_foreward
# 22 => 23: do action: stop
# last_move: point_foreward | inp: point_up
# 23 => 24: do action: reload
# last_move: point_up | inp: point_foreward
# 24 => 25: do action: stop
# last_move: point_foreward | inp: curl
# 25 => 26: do action: shoot
# last_move: curl | inp: point_foreward
# 26 => 27: do action: stop
# last_move: point_foreward | inp: point_foreward
# 27 => 28: do action: stop
# last_move: point_foreward | inp: point_foreward
# 28 => 29: do action: stop
# last_move: point_foreward | inp: point_up
# 29 => 30: do action: reload
# last_move: point_up | inp: curl
# 30 => 31: do action: shoot
# last_move: curl | inp: point_up
# 31 => 32: do action: reload
# last_move: point_up | inp: curl
# 32 => 33: do action: shoot
# last_move: curl | inp: point_up
# 33 => 34: do action: reload
# last_move: point_up | inp: point_foreward
# 34 => 35: do action: stop
# last_move: point_foreward | inp: point_up
# 35 => 36: do action: reload
# last_move: point_up | inp: point_foreward
# 36 => 37: do action: stop
# last_move: point_foreward | inp: curl
# 37 => 38: do action: shoot
# last_move: curl | inp: curl
# 38 => 39: do action: shoot
# last_move: curl | inp: curl
# 39 => 40: do action: shoot
# last_move: curl | inp: curl
# 40 => 41: do action: shoot
# last_move: curl | inp: curl
# 41 => 42: do action: shoot
# last_move: curl | inp: point_foreward
# 42 => 43: do action: stop
# last_move: point_foreward | inp: point_foreward
# 43 => 44: do action: stop
# last_move: point_foreward | inp: curl
# 44 => 45: do action: shoot
# last_move: curl | inp: curl
# 45 => 46: do action: shoot
# last_move: curl | inp: curl
# 46 => 47: do action: shoot
# last_move: curl | inp: curl
# 47 => 48: do action: shoot
# last_move: curl | inp: point_up
# 48 => 49: do action: reload
# last_move: point_up | inp: point_up
# 49 => 50: do action: reload
# last_move: point_up | inp: point_up
# 50 => 51: do action: reload
# last_move: point_up | inp: curl
# 51 => 52: do action: shoot
# last_move: curl | inp: curl
# 52 => 53: do action: shoot
# last_move: curl | inp: point_foreward
# 53 => 54: do action: stop
# last_move: point_foreward | inp: point_foreward
# 54 => 55: do action: stop
# last_move: point_foreward | inp: point_up
# 55 => 56: do action: reload
# last_move: point_up | inp: point_foreward
# 56 => 57: do action: stop
# last_move: point_foreward | inp: point_foreward
# 57 => 58: do action: stop
# last_move: point_foreward | inp: point_up
# 58 => 59: do action: reload
# last_move: point_up | inp: point_foreward
# 59 => 60: do action: stop
# last_move: point_foreward | inp: point_up
# 60 => 61: do action: reload
# last_move: point_up | inp: point_up
# 61 => 62: do action: reload
# last_move: point_up | inp: curl
# 62 => 63: do action: shoot
# last_move: curl | inp: point_foreward
# 63 => 64: do action: stop
# last_move: point_foreward | inp: curl
# 64 => 65: do action: shoot
# last_move: curl | inp: point_up
# 65 => 66: do action: reload
# last_move: point_up | inp: point_up
# 66 => 67: do action: reload
# last_move: point_up | inp: point_up
# 67 => 68: do action: reload
# last_move: point_up | inp: curl
# 68 => 69: do action: shoot
# last_move: curl | inp: curl
# 69 => 70: do action: shoot
# last_move: curl | inp: curl
# 70 => 71: do action: shoot
# last_move: curl | inp: curl
# 71 => 72: do action: shoot
# last_move: curl | inp: curl
# 72 => 73: do action: shoot
# last_move: curl | inp: point_foreward
# 73 => 74: do action: stop
# last_move: point_foreward | inp: curl
# 74 => 75: do action: shoot
# last_move: curl | inp: point_up
# 75 => 76: do action: reload
# last_move: point_up | inp: curl
# 76 => 77: do action: shoot
# last_move: curl | inp: curl
# 77 => 78: do action: shoot
# last_move: curl | inp: curl
# 78 => 79: do action: shoot
# last_move: curl | inp: point_up
# 79 => 80: do action: reload
# last_move: point_up | inp: point_up
# 80 => 81: do action: reload
# last_move: point_up | inp: point_up
# 81 => 82: do action: reload
# last_move: point_up | inp: point_foreward
# 82 => 83: do action: stop
# last_move: point_foreward | inp: curl
# 83 => 84: do action: shoot
# last_move: curl | inp: point_up
# 84 => 85: do action: reload
# last_move: point_up | inp: curl
# 85 => 86: do action: shoot
# last_move: curl | inp: curl
# 86 => 87: do action: shoot
# last_move: curl | inp: point_foreward
# 87 => 88: do action: stop
# last_move: point_foreward | inp: point_foreward
# 88 => 89: do action: stop
# last_move: point_foreward | inp: point_foreward
# 89 => 90: do action: stop
# last_move: point_foreward | inp: curl
# 90 => 91: do action: shoot
# last_move: curl | inp: point_up
# 91 => 92: do action: reload
# last_move: point_up | inp: point_foreward
# 92 => 93: do action: stop
# last_move: point_foreward | inp: point_foreward
# 93 => 94: do action: stop
# last_move: point_foreward | inp: point_foreward
# 94 => 95: do action: stop
# last_move: point_foreward | inp: curl
# 95 => 96: do action: shoot
# last_move: curl | inp: point_up
# 96 => 97: do action: reload
# last_move: point_up | inp: curl
# 97 => 98: do action: shoot
# last_move: curl | inp: point_foreward
# 98 => 99: do action: stop

# %%
output_dir = 'E:/ar_fps/action_perception/frames'

# %%
cap = cv2.VideoCapture('E:/ar_fps/gameplay.mp4')

# %%
# extract frames

# init_box = None
# tracker = cv2.TrackerKCF_create()

# x_start = 200
# y_start = 200
# width = 125
# height = 125

# _, frame = cap.read()
# frames = [frame]
# box = cv2.selectROI('Frame', frame, fromCenter=False, showCrosshair=True)
# tracked_boxes = [box]
# tracker = cv2.TrackerKCF_create()
# tracker.init(frame, box)
# i = 1
# while True:
#     ret, frame = cap.read()
    
#     if not ret:
#         break
       
#     orig = frame.copy()
#     ret, box = tracker.update(orig)

#     if ret:
#         x, y, w, h = map(int, box)
#         cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 3, 1)
#     else:
#         box = cv2.selectROI('Frame', frame, fromCenter=False, showCrosshair=True)
#         tracker = cv2.TrackerKCF_create()
#         tracker.init(orig, box)
        
        
#     frames.append(orig)
#     tracked_boxes.append(box)
        
#     cv2.waitKey(10) & 0xff
#     cv2.imshow('img', frame)
    
#     i += 1

# cap.release()
# cv2.destroyAllWindows()

# %%
# with open('gameplay_data.txt', 'w') as f:
#     for box in tracked_boxes:
        
#         f.write(','.join(list(map(str, box))) + '\n')

# %%
tracked_boxes = []
with open('gameplay_data.txt', 'rb') as f:
    while True:
        line = f.readline()
        if line:
            line = line.decode('utf-8').split('\r\n')[0]
            box = list(map(int, map(float, line.split(','))))
            tracked_boxes.append(box)
        else: 
            break

# %%
from utils import *

# %%
model = load_classifier()

# %%
for i, frame in enumerate(frames):
    box = tracked_boxes[i]
    x, y, w, h = map(int, box)
    crop = frame[y:y+h, x:x+w]
    
    # preprocess
    img = cv2.resize(crop, (75, 75))
    batch = np.expand_dims(img, axis=0).astype(np.float32)
    
    # run prediction
    res = model.predict(batch)
    pred_ind = np.argmax(res[0])
    pred = labels[pred_ind]
    print(res)
    disp = frame.copy()
#     cv2.rectangle(crop, (x, y), (x + w, y + h), (0, 255, 0), 3, 1)
    cv2.putText(crop, pred, (0, 20), cv2.FONT_HERSHEY_COMPLEX, 0.5, (0,255,0), 1)
    k = cv2.waitKey(30) & 0xff
    if k == ord('q'):
        break
        
    cv2.imshow('img', crop)
       
cv2.destroyAllWindows()
